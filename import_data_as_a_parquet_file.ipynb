# %% [markdown]
# <a href="https://colab.research.google.com/github/Yui411/test/blob/main/import_data_as_a_parquet_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cybersecurity Attacks - Export data as a parquet format

# %%
# Import libraries
import pandas as pd
import requests
import json
import requests
import json
import time

# %%
# Load the dataset
from google.colab import files
uploaded = files.upload()
df = pd.read_csv("cybersecurity_attacks.csv")

df.to_parquet("cybersecurity_attacks.parquet")

files.download("cybersecurity_attacks.parquet")
# Out:
#      <input type="file" id="files-902c2e34-e416-46d1-8130-a8d4c3f085bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-902c2e34-e416-46d1-8130-a8d4c3f085bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## Cannot use in my env.

# %%
# # My Databricks info
# DATABRICKS_INSTANCE = "https://dbc-caf21b48-64cb.cloud.databricks.com/"
# DATABRICKS_TOKEN = "HIDE MY INFO"

# CATALOG = "cctb_catalog"
# SCHEMA = "final_project"
# TABLE = "cybersecurity_attacks"

# %%
# import pandas as pd

# from google.colab import files
# uploaded = files.upload()
# df = pd.read_csv("cybersecurity_attacks.csv")
# Out:
#      <input type="file" id="files-55253fea-4dad-404f-a8ab-84ab90378206" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-55253fea-4dad-404f-a8ab-84ab90378206">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# # Data insert query function

# def insert_row_to_databricks(row_dict):
#     # generate sql
#     columns = ", ".join([f"`{col}`" for col in row_dict.keys()])
#     values = ", ".join([f"'{str(val)}'" for val in row_dict.values()])

#     sql = f"""
#     INSERT INTO {CATALOG}.{SCHEMA}.{TABLE} ({columns})
#     VALUES ({values});
#     """

#     payload = {
#         "statement": sql,
#         "wait_timeout": "180",  # sec
#         "warehouse_id": "5fc34a13dbd434e5"
#     }

#     r = requests.post(
#         f"{DATABRICKS_INSTANCE}/api/2.0/sql/statements",
#         headers={"Authorization": f"Bearer {DATABRICKS_TOKEN}"},
#         json=payload
#     )

#     if r.status_code != 200:
#         print("Error:", r.text)
#     else:
#         print("Inserted one row.")

# %%
# cols = [
#     'Timestamp', 'Source IP Address', 'Destination IP Address',
#     'Source Port', 'Destination Port', 'Protocol', 'Packet Length',
#     'Packet Type', 'Traffic Type', 'Payload Data', 'Malware Indicators',
#     'Anomaly Scores', 'Alerts/Warnings', 'Attack Type', 'Attack Signature',
#     'Action Taken', 'Severity Level', 'User Information', 'Device Information',
#     'Network Segment', 'Geo-location Data', 'Proxy Information', 'Firewall Logs',
#     'IDS/IPS Alerts', 'Log Source'
# ]

# df = df[cols]

# %%
# for idx, row in df.iterrows():
#     insert_row_to_databricks(row.to_dict())
#     time.sleep(0.3)  # Rate limit
# Out:
# Error: {"error_code":"INVALID_PARAMETER_VALUE","message":"Error while parsing type: duration.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"7f9aa9e1-d595-4532-b5a8-173e442fb885","serving_data":""}]}
# Error: {"error_code":"INVALID_PARAMETER_VALUE","message":"Error while parsing type: duration.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"c67b618f-0966-4471-9f6a-853b27f037c1","serving_data":""}]}
# Error: {"error_code":"INVALID_PARAMETER_VALUE","message":"Error while parsing type: duration.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"c0f81662-1e6b-4d49-87ff-c98880adc024","serving_data":""}]}
# Error: {"error_code":"INVALID_PARAMETER_VALUE","message":"Error while parsing type: duration.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"f7e359e8-58d1-4459-9e29-82abaa9a77d7","serving_data":""}]}
# ...
